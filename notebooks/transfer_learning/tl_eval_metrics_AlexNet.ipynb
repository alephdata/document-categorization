# %%
import os

import pandas as pd

metrics_path = os.path.join(
    "/data/dssg/occrp/data/weights/transfer_learning/AlexNet_2022_07_14-16_59_12/assessment", "training_ev_metrics.csv"
)
metrics_table = pd.read_csv(metrics_path)


metrics_table_loss = metrics_table[["loss", "val_loss"]]
metrics_table_accuracy = metrics_table[["accuracy", "val_accuracy"]]


metrics_table_loss.reset_index().plot(x="index", y=metrics_table_loss.columns)
metrics_table_accuracy.reset_index().plot(x="index", y=metrics_table_accuracy.columns)
# Out:
# <AxesSubplot:xlabel='index'>
